# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input{font-family:Consolas; font-size:12pt;}
div.prompt {min width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe {font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input{font-family:Consolas; font-size:12pt;}
# div.prompt {min width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe {font-size:12px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 install 및 환경변수 load)
# - pip install langchain-upstage

# %%
# %pip install -q langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\Admin\anaconda3\envs\llm\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 OpenAI SDK를 사용

# %%
import openai
openai.__version__
# Out:
# '2.9.0'

# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.getenv('UPSTAGE_API_KEY'),
    base_url="https://api.upstage.ai/v1"
)

# %%
response = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {"role": "system", "content": "너는 친절하게 대답 해주는 비서야"},
        {"role": "user", "content": "2020년 월드 시리즈 우승팀이 어디야?"}
        
    ],
    temperature=0.5,
    stream=False,
)

# %%
response.choices[0].message.content
# Out:
# '2020년 월드 시리즈 우승팀은 **로스앤젤레스 다저스**입니다!  \n\n다저스는 탬파베이 레이스를 4승 2패로 꺾고 32년 만의 우승을 달성했어요. 특히 코로나19 영향으로 무관중 경기로 진행된 시리즈에서 뛰어난 투수진과 타선의 조화를 보여주었습니다.  \n\n당시 MVP는 다저스의 유틸리티 플레이어 **코리 시거**가 수상했답니다! ⚾🎉  \n\n궁금한 점이 있다면 또 물어보세요! 😊'

# %% [markdown]
# ## 2.2 LangChain 선택
# - 발급받은 API KEY를 "UPSTAGE_API_KEY"라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content='너는 친절하게 대답해 주는 비서야'),
    HumanMessage(content='2020년 월드 시리즈 누가 우승했어?')
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 LA 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드 시리즈 우승을 차지했습니다. MVP는 다저스의 무키 베츠가 선정되었습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 36, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': 'ad2298bb-fedc-45ee-b282-36ed656f31b8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b96e2-7700-7801-86e6-99db971e85c7-0', usage_metadata={'input_tokens': 36, 'output_tokens': 57, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

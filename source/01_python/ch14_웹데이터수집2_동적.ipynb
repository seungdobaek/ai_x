# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input{font-family:Consolas; font-size:12pt;}
div.prompt {min width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe {font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input{font-family:Consolas; font-size:12pt;}
# div.prompt {min width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe {font-size:12px;}
# </style>

# %% [markdown]
# <b><font size='6' color='red'>ch14 웹데이터 수집 동적</font></b>
# # 1절. Seleninum을 이용한 동적 웹크롤링 문법
# `pip install selenium`
# - import에서 에러날 경우 `pip install requests`나 `conda install urllib3=1.26.18`을 사용
# - https://selenium-python.readthedocs.io/

# %%
#%pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#      ---------------------------------------- 9.7/9.7 MB 5.0 MB/s eta 0:00:00
# Collecting websocket-client<2.0,>=1.8.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.6/82.6 kB 4.5 MB/s eta 0:00:00
# Collecting urllib3[socks]<3.0,>=2.5.0
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      -------------------------------------- 129.8/129.8 kB 7.5 MB/s eta 0:00:00
# Collecting trio-websocket<1.0,>=0.12.2
#   Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Collecting typing_extensions<5.0,>=4.15.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.6/44.6 kB 2.1 MB/s eta 0:00:00
# Collecting certifi>=2025.10.5
#   Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#      -------------------------------------- 159.4/159.4 kB 9.9 MB/s eta 0:00:00
# Collecting trio<1.0,>=0.31.0
#   Downloading trio-0.32.0-py3-none-any.whl (512 kB)
#      ------------------------------------- 512.0/512.0 kB 10.7 MB/s eta 0:00:00
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting attrs>=23.2.0
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.6/67.6 kB 3.6 MB/s eta 0:00:00
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\users\admin\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.3.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\admin\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Collecting h11<1,>=0.16.0
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: websocket-client, urllib3, typing_extensions, sniffio, h11, certifi, attrs, wsproto, outcome, exceptiongroup, trio, trio-websocket, selenium
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.8.3
#     Uninstalling certifi-2025.8.3:
#       Successfully uninstalled certifi-2025.8.3
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# Successfully installed attrs-25.4.0 certifi-2025.11.12 exceptiongroup-1.3.0 h11-0.16.0 outcome-1.3.0.post0 selenium-4.38.0 sniffio-1.3.1 trio-0.32.0 trio-websocket-0.12.2 typing_extensions-4.15.0 urllib3-2.5.0 websocket-client-1.9.0 wsproto-1.3.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# requests 2.28.1 requires urllib3<1.27,>=1.21.1, but you have urllib3 2.5.0 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get('http://www.python.org')

# %%
elem = driver.find_element(By.NAME, 'q')
elem.clear()
elem.send_keys('pycon')

# %%
from selenium.webdriver.common.keys import Keys
elem.send_keys(Keys.RETURN) # Enter를 입력

# %%
btn_elem = driver.find_element(By.CSS_SELECTOR, 'button#submit')
btn_elem.click()

# %%
result_list = driver.find_elements(By.CSS_SELECTOR, 'li > h3 > a')
for result in result_list:
    title = result.text
    link = result.get_attribute('href')
    print('{} - {}'.format(title, link))
# Out:
# PSF PyCon Trademark Usage Policy - https://www.python.org/psf/trademarks/pycon
# PyCon Italia 2016 (PyCon Sette) - https://www.python.org/events/python-events/378/
# PyCon Australia 2013 - https://www.python.org/events/python-events/57/
# PyCon AU 2019 - https://www.python.org/events/python-events/776/
# PyCon NL 2025 - https://www.python.org/events/python-events/2084/
# PyCon Australia 2014 - https://www.python.org/events/python-events/10/
# PyCon Ireland 2012 - https://www.python.org/events/python-events/76/
# PyCon Ireland 2016 - https://www.python.org/events/python-events/429/
# PyCon Ireland 2022 - https://www.python.org/events/python-events/1320/
# PyCon Australia 2014 - https://www.python.org/events/python-events/1447/
# PyCon Ireland 2024 - https://www.python.org/events/python-events/1862/
# PyCon APAC 2025 - https://www.python.org/events/python-events/1879/
# PyCon AU 2018 - https://www.python.org/events/python-events/696/
# PyCon APAC 2022 - https://www.python.org/events/python-events/1216/
# PyCon PH 2024 - https://www.python.org/events/python-events/1661/
# PyCon Ireland 2023 - https://www.python.org/events/python-events/1568/
# PyCon PL 2014 - https://www.python.org/events/python-events/191/
# PyCon MY 2015 - https://www.python.org/events/python-events/313/
# PyCon Ireland 2015 - https://www.python.org/events/python-events/333/
# PyCon AU 2015 - https://www.python.org/events/python-events/273/

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')
result_list = soup.select('li > h3 > a')
for result in result_list:
    print("{} - {}".format(result.text, result.attrs['href']))
# Out:
# PSF PyCon Trademark Usage Policy - /psf/trademarks/pycon
# PyCon Italia 2016 (PyCon Sette) - /events/python-events/378/
# PyCon Australia 2013 - /events/python-events/57/
# PyCon AU 2019 - /events/python-events/776/
# PyCon NL 2025 - /events/python-events/2084/
# PyCon Australia 2014 - /events/python-events/10/
# PyCon Ireland 2012 - /events/python-events/76/
# PyCon Ireland 2016 - /events/python-events/429/
# PyCon Ireland 2022 - /events/python-events/1320/
# PyCon Australia 2014 - /events/python-events/1447/
# PyCon Ireland 2024 - /events/python-events/1862/
# PyCon APAC 2025 - /events/python-events/1879/
# PyCon AU 2018 - /events/python-events/696/
# PyCon APAC 2022 - /events/python-events/1216/
# PyCon PH 2024 - /events/python-events/1661/
# PyCon Ireland 2023 - /events/python-events/1568/
# PyCon PL 2014 - /events/python-events/191/
# PyCon MY 2015 - /events/python-events/313/
# PyCon Ireland 2015 - /events/python-events/333/
# PyCon AU 2015 - /events/python-events/273/

# %%
from urllib.parse import urlparse
current_url = driver.current_url # 셀레니움을 통해 접근한 url
print(current_url)
parse_url = urlparse(current_url)
print(parse_url)
domain = f'{parse_url.scheme}://{parse_url.netloc}'
print(domain)
# Out:
# https://www.python.org/search/?q=pycon&submit=
# ParseResult(scheme='https', netloc='www.python.org', path='/search/', params='', query='q=pycon&submit=', fragment='')
# https://www.python.org

# %%
result_list = soup.select('li > h3 > a')
for result in result_list:
    print("{} - {}".format(result.text, domain+result.attrs['href']))
# Out:
# PSF PyCon Trademark Usage Policy - https://www.python.org/psf/trademarks/pycon
# PyCon Italia 2016 (PyCon Sette) - https://www.python.org/events/python-events/378/
# PyCon Australia 2013 - https://www.python.org/events/python-events/57/
# PyCon AU 2019 - https://www.python.org/events/python-events/776/
# PyCon NL 2025 - https://www.python.org/events/python-events/2084/
# PyCon Australia 2014 - https://www.python.org/events/python-events/10/
# PyCon Ireland 2012 - https://www.python.org/events/python-events/76/
# PyCon Ireland 2016 - https://www.python.org/events/python-events/429/
# PyCon Ireland 2022 - https://www.python.org/events/python-events/1320/
# PyCon Australia 2014 - https://www.python.org/events/python-events/1447/
# PyCon Ireland 2024 - https://www.python.org/events/python-events/1862/
# PyCon APAC 2025 - https://www.python.org/events/python-events/1879/
# PyCon AU 2018 - https://www.python.org/events/python-events/696/
# PyCon APAC 2022 - https://www.python.org/events/python-events/1216/
# PyCon PH 2024 - https://www.python.org/events/python-events/1661/
# PyCon Ireland 2023 - https://www.python.org/events/python-events/1568/
# PyCon PL 2014 - https://www.python.org/events/python-events/191/
# PyCon MY 2015 - https://www.python.org/events/python-events/313/
# PyCon Ireland 2015 - https://www.python.org/events/python-events/333/
# PyCon AU 2015 - https://www.python.org/events/python-events/273/

# %%
driver.close() #브라우저 종료

# %% [markdown]
#  # 2절. 동적웹크롤링 예제
#  ## 2.1 다음 뉴스 검색

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()
driver.get('https://www.daum.net/')
#driver.implicitly_wait(0.5) # 최대 0.5초 동안 대기
time.sleep(0.5)
# driver.find_element(By.CLASS_NAME, 'tf_keyword').click()
query = input('검색할 단어는?')
driver.find_element(By.CSS_SELECTOR, 'input[type="text"]').send_keys(query)
driver.find_element(By.CLASS_NAME, 'btn_ksearch').click()
# Out:
# 검색할 단어는?비트코인

# %%
#뉴스탭 클릭
# driver.find_elements(By.CSS_SELECTOR, 'ul.list_tab > li')[1].click()
driver.find_element(By.LINK_TEXT, '뉴스').click()

# %%
#뉴스제목과 link를 list에 추가
news_list = []
strongs = driver.find_elements(By.CSS_SELECTOR, 'div.item-title > strong')
# print(len(strongs))
for strong in strongs:
    a = strong.find_element(By.TAG_NAME, 'a')
    title = a.text
    link = a.get_attribute('href')
    #print(title, link)
    news_list.append([title,link])

# %%
#다음페이지로
page_nav = driver.find_element(By.CSS_SELECTOR, 'div.inner_paging')
next_page = page_nav.find_element(By.LINK_TEXT, '2')
next_page.click()

# %%
driver.close()

# %% [markdown]
# ## 2.2 페이징 처리
# - 다음 뉴스 페이징 처리 : 원하는 keyword를 원하는 페이지만큼 조회

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.daum.net/')
#driver.implicitly_wait(0.5) # 최대 0.5초 동안 대기
time.sleep(0.5)
driver.find_element(By.CLASS_NAME, 'tf_keyword').click()
query = input('검색할 단어는?')
driver.find_element(By.CSS_SELECTOR, 'input[type="text"]').send_keys(query)
driver.find_element(By.CLASS_NAME, 'btn_ksearch').click()
time.sleep(2)

# 뉴스탭 이동
driver.find_element(By.LINK_TEXT, '뉴스').click()

#뉴스제목과 link를 list에 추가
news_list = []
pages = 3
for page in range(1, pages+1):
    strongs = driver.find_elements(By.CSS_SELECTOR, 'div.item-title > strong')
    # print(len(strongs))
    for strong in strongs:
        a = strong.find_element(By.TAG_NAME, 'a')
        title = a.text
        link = a.get_attribute('href')
        #print(title, link)
        news_list.append([title,link])
    page_nav = driver.find_element(By.CSS_SELECTOR, 'div.inner_paging')
    page_nav.find_element(By.LINK_TEXT, str(page+1)).click()
    time.sleep(2)
driver.close()

pd.DataFrame(news_list, columns=['title', 'link'])
# Out:
# 검색할 단어는?비트코인
#                                                 title  \
# 0                          가상자산 일제히 급락… 비트코인 10만달러 위태
# 1          중국 '가상화폐 여왕' 털자 비트코인 9조 '와르르'...도망간 영국서 실형
# 2              [ET단상] 뒷전 된 대국민 투자기회…5년 늦은 비트코인 현물 ETF
# 3         "연말에는 오를까"…비트코인, ETF 자금 유입 저조에 1억5400만원대 후퇴
# 4       ‘9조 비트코인 여왕’ 런던 집 침대서 체포된 순간…징역 11년8개월 [지금뉴스]
# 5                       큰손들은 털고 나간다…비트코인 10만 달러 붕괴 조짐
# 6                        英, 9조 비트코인 세탁 중국인에 징역 11년8개월
# 7           "비트코인 9조 최대 압수"...'중국 가상화폐 여왕' 영국서 징역 11년
# 8   '초대박이네' 금·비트코인·주식·부동산 다 필요없다! 최고의 투자 종목은 오타니 루...
# 9            “새로운 기부라고 생각” 서울대병원에 1비트코인 기부한 70대…가격 보니
# 10           "최대 12배 간다"…국내 인기코인 리플, 이르면 내일 현물 ETF 출시
# 11              “내 꿈은 리버랜드 군주”…비트코인 9조 세탁하다 잡힌 중국인의 꿈
# 12                     압수 비트코인만 9조…13만명에 사기 친 중국인의 최후
# 13              '조정은 기회'…가상자산 대형 보유사들, BTC·ETH 공격적 매입
# 14              "새로운 기부 도구"…'비트코인 1개' 서울대병원에 기부한 70대男
# 15        "셧다운 해제 코인 폭발할까"…비트코인 1억5700만원대 회복, 리플은 7%↑
# 16            '9조 비트코인 사기' 40대 여성, 월세 3000만원 집 살더니 결국
# 17      영국서 초호화생활 중국인 여성 중형, 왜?…다단계 사기로 ‘비트코인 10조’ 세탁
# 18          비트코인, 美 정부 셧다운 해제 관망에 10만6000달러선 [크립토브리핑]
# 19             영국 뒤흔든 ‘가상화폐 여왕’…中 여성, 9조 비트코인으로 호화 도피
# 20              꿈틀대던 비트코인, 다시 10.5만달러대…'고래 매도' 조정 신호?
# 21                   탈중앙화 금융의 위기와 프라이버시 코인의 부상[엠블록레터]
# 22            비트코인, 현물 ETF 유입 침체에 10만2000달러선 [크립토브리핑]
# 23            압수 비트코인만 9조원···사기친 돈 세탁한 중국인 영국서 징역 11년
# 24                경제학자들 “원화 스테이블코인 도입 신중해야···코인런 우려돼”
# 25  "美 셧다운 풀리면 XRP 현물 ETF 러시"…'알트코인 랠리' 올까 [강민승의 알...
# 26        다단계 사기로 갈취한 비트코인만 9조··· 중국인, 英서 ‘중형’[글로벌 왓]
# 27      불장에 코인 거래대금은 연초 대비 7분의 1 뚝… 거래소 ‘1억 상금’ 유치전까지
# 28           비트코인 ETF 막힌 한국…서학개미, 미국 레버리지로 '우회 매수' 급증
# 29                       압수된 비트코인 9조 자금세탁…40대 중국인 징역형
#
#                                      link
# 0   http://v.daum.net/v/20251112080939100
# 1   http://v.daum.net/v/20251112100711544
# 2   http://v.daum.net/v/20251112160328227
# 3   http://v.daum.net/v/20251112095516978
# 4   http://v.daum.net/v/20251112160748420
# 5   http://v.daum.net/v/20251112082149370
# 6   http://v.daum.net/v/20251112100549482
# 7   http://v.daum.net/v/20251112064009731
# 8   http://v.daum.net/v/20251112050138492
# 9   http://v.daum.net/v/20251112064050739
# 10  http://v.daum.net/v/20251112153215561
# 11  http://v.daum.net/v/20251112113003074
# 12  http://v.daum.net/v/20251112105939253
# 13  http://v.daum.net/v/20251112125738564
# 14  http://v.daum.net/v/20251112014938537
# 15  http://v.daum.net/v/20251111094914124
# 16  http://v.daum.net/v/20251112072538299
# 17  http://v.daum.net/v/20251112093904308
# 18  http://v.daum.net/v/20251111103648808
# 19  http://v.daum.net/v/20251112105013730
# 20  http://v.daum.net/v/20251111161648648
# 21  http://v.daum.net/v/20251112162402175
# 22  http://v.daum.net/v/20251112103550898
# 23  http://v.daum.net/v/20251112094247439
# 24  http://v.daum.net/v/20251112160647363
# 25  http://v.daum.net/v/20251112144248097
# 26  http://v.daum.net/v/20251112103914094
# 27  http://v.daum.net/v/20251112154826414
# 28  http://v.daum.net/v/20251111140546725
# 29  http://v.daum.net/v/20251112072049232

# %% [markdown]
# ## 2.3 맞춤법 검사기
# - 네이버 맞춤법 검사기 이용

# %%
from bs4 import BeautifulSoup

driver = webdriver.Chrome()
driver.get('https://www.naver.com')
time.sleep(1)
elem = driver.find_element(By.ID, 'query')
elem.send_keys('맞춤법 검사기')
elem.send_keys(Keys.RETURN)
time.sleep(1)

textarea = driver.find_element(By.CSS_SELECTOR, 'textarea.txt_gray')
textarea.clear()
textarea.send_keys('안뇽하세요 반갑숩니다 감사합니다')
driver.find_element(By.CLASS_NAME, 'btn_check').click()
time.sleep(3)
# txt_result = driver.find_element(By.CSS_SELECTOR, 'p._result_text.stand_txt').text
# print(txt_result)

soup = BeautifulSoup(driver.page_source, 'html.parser')
result = soup.select_one('p._result_text.stand_txt').text
print(result)
driver.close()
# Out:
# 안녕하세요 반갑습니다 감사합니다

# %% [markdown]
# - 설화.txt 읽어 300자 단위로 짤라 list에 넣어 동적웹크롤링 한후, 결과 출력 (설화_맞춤법후.txt)

# %%
with open('data/ch14_설화.txt', 'r', encoding='utf-8') as f:
    temp_text = f.read()
ready_text = [] #300자씩 나눠진 text
text = temp_text
while(len(text) > 300):
    temp = text[:300]
    last_dot_index = temp.rfind('\n')
    ready_text.append(text[:last_dot_index])
    text = text[last_dot_index+1 : ]
ready_text.append(text)
# print(ready_text)
# print([len(ready) for ready in ready_text])

driver = webdriver.Chrome()
driver.get('https://www.naver.com')
time.sleep(1)
elem = driver.find_element(By.ID, 'query')
elem.send_keys('맞춤법 검사기')
elem.send_keys(Keys.RETURN)
time.sleep(1)

textarea = driver.find_element(By.CSS_SELECTOR, 'textarea.txt_gray')
btn = driver.find_element(By.CLASS_NAME, 'btn_check')
results = '' #맞춤법 검사 완료된 test
for i, ready in enumerate(ready_text):
    print(f'검사중...{i+1}/{len(ready_text)}')
    textarea.clear()
    #textarea.send_keys(Keys.CONTROL, 'a') #ctrl-a
    textarea.send_keys(ready)
    btn.click()
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    result = soup.select_one('p._result_text.stand_txt').text
    results += result + '\n'
    time.sleep(1)
driver.close()
# Out:
# [234, 239]
# 검사중...1/2
# 검사중...2/2

# %%
with open('data/설화_맞춤법후.txt', 'w', encoding='utf-8') as f:
    f.write(results)

# %%
# 영어번역 자동화 프로그램
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup

with open('data/설화_맞춤법후.txt', 'r', encoding='utf-8') as f:
    text = f.read()

driver = webdriver.Chrome()
driver.get('https://papago.naver.com/')
time.sleep(1)
driver.find_element(By.ID, 'txtSource').send_keys(text)
driver.find_element(By.ID, 'btnTranslate').click()
time.sleep(3)
soup = BeautifulSoup(driver.page_source, 'html.parser')
texts = soup.select('div#txtTarget > span')
text=''
for temp in texts:
    text += temp.text + '\n'
print(text)
driver.close()

with open('data/설화_자동화번역본.txt', 'w', encoding='utf-8') as f:
    f.write(text)
# Out:
# Once upon a time, there lived a young man named Potato Doryeong in a mountain village. He is said to have loved potatoes so much that he gave them potatoes for breakfast, potatoes for lunch, and even on dates. One day, a doryeong who was selling French fries at a village marketplace threw potatoes into the sky when there are no customers, and the potatoes hit the passing dragon's nose! The dragon held his nose and came down with thunder and lightning, saying, "Who's bothering my nose!"
# The potato master was scared, but soon he passed the fried potatoes to the dragon. As the dragon took a bite, his eyes widened and he said, "What's this! This is the best potato in the world!" So, the dragon rained on the village and gave the master a bag of golden potatoes. Since then, the master has been called the potato king and said to have lived a good life. However, he sometimes looks at the sky and says, "Oh, if I hadn't thrown the potatoes at that time, I wouldn't have been this busy frying potatoes…"" It is said that he grumbled.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://papago.naver.com/')
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, 'button#ddTargetLanguageButton').click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, 'div#ddTargetLanguage li:nth-child(8) a').click()

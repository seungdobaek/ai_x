# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input{font-family:Consolas; font-size:12pt;}
div.prompt {min width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe {font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input{font-family:Consolas; font-size:12pt;}
# div.prompt {min width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe {font-size:12px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense # 모델 layer 쌓을때
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])

# 2. 모델 구성
model = Sequential()
model.add(Dense(units=10, # 출력갯수
                input_dim=2, #input_shape=(2,) # 입력갯수,
                activation='relu')) #활성화 함수
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
# loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석), 
#         categorical_crossentropy(다중분류-원핫인코딩을 한 경우), sparse_categorical_entropy(다중분류-원핫인코딩 안 한 경우)
model.compile(loss='binary_crossentropy', #손실함수 (loss function)
              optimizer='adam',
              metrics=['binary_accuracy']) #2진분류
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 10)                30
#
#  dense_8 (Dense)             (None, 20)                220
#
#  dense_9 (Dense)             (None, 10)                210
#
#  dense_10 (Dense)            (None, 1)                 11
#
# ...
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 학습
hist = model.fit(x_data, y_data, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 0.7114 - binary_accuracy: 0.5000 - 523ms/epoch - 523ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.7086 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.7056 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.7024 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6992 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6962 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6935 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6910 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6885 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6861 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6836 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 12/300
# ...

# %%
# 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc = 'center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data) # loss & metrics(binary accuracy)
print('loss :', score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0404 - binary_accuracy: 1.0000
# loss : 0.04043405503034592
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0,1]]))
# Out:
# 1/1 [==============================] - 0s 61ms/step
# array([[0.9321175]], dtype=float32)
